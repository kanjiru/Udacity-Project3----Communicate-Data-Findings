# %% [markdown]
# # Part I - (Dataset Exploration Title)
# ## by Solomon Kamau
#
# ## Introduction
#
# >This data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area for the year 2019.
#
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style('darkgrid')
sb.set(font_scale=1.3)

# %matplotlib inline

# %%
df =pd.read_csv('201902-fordgobike-tripdata.csv')

# %%
df.shape
# Out:
# (174952, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174952 entries, 0 to 174951
# Data columns (total 25 columns):
# duration_sec               174952 non-null int64
# start_time                 174952 non-null object
# end_time                   174952 non-null object
# start_station_id           174952 non-null float64
# start_station_name         174952 non-null object
# start_station_latitude     174952 non-null float64
# start_station_longitude    174952 non-null float64
# end_station_id             174952 non-null float64
# end_station_name           174952 non-null object
# end_station_latitude       174952 non-null float64
# end_station_longitude      174952 non-null float64
# bike_id                    174952 non-null int64
# user_type                  174952 non-null object
# member_birth_year          174952 non-null float64
# member_gender              174952 non-null object
# bike_share_for_all_trip    174952 non-null object
# ...

# %%
df.head()
# Out:
#    duration_sec               start_time                 end_time  \
# 0         52185  2019-02-28 17:32:10.145  2019-03-01 08:01:55.975
# 1         61854  2019-02-28 12:13:13.218  2019-03-01 05:24:08.146
# 2         36490  2019-02-28 17:54:26.010  2019-03-01 04:02:36.842
# 3          1585  2019-02-28 23:54:18.549  2019-03-01 00:20:44.074
# 4          1793  2019-02-28 23:49:58.632  2019-03-01 00:19:51.760
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              86.0                           Market St at Dolores St
# 2             375.0                           Grove St at Masonic Ave
# 3               7.0                               Frank H Ogawa Plaza
# 4              93.0                      4th St at Mission Bay Blvd S
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# ...

# %%
df.tail()
# Out:
#         duration_sec               start_time                 end_time  \
# 174947           480  2019-02-01 00:04:49.724  2019-02-01 00:12:50.034
# 174948           313  2019-02-01 00:05:34.744  2019-02-01 00:10:48.502
# 174949           141  2019-02-01 00:06:05.549  2019-02-01 00:08:27.220
# 174950           139  2019-02-01 00:05:34.360  2019-02-01 00:07:54.287
# 174951           271  2019-02-01 00:00:20.636  2019-02-01 00:04:52.058
#
#         start_station_id                                start_station_name  \
# 174947              27.0                           Beale St at Harrison St
# 174948              21.0  Montgomery St BART Station (Market St at 2nd St)
# 174949             278.0                            The Alameda at Bush St
# 174950             220.0                       San Pablo Ave at MLK Jr Way
# 174951              24.0                             Spear St at Folsom St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  174952.000000     174952.000000           174952.000000
# mean      704.002744        139.002126               37.771220
# std      1642.204905        111.648819                0.100391
# min        61.000000          3.000000               37.317298
# 25%       323.000000         47.000000               37.770407
# 50%       510.000000        104.000000               37.780760
# 75%       789.000000        239.000000               37.797320
# max     84548.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            174952.000000   174952.000000         174952.000000
# mean               -122.351760      136.604486             37.771414
# std                   0.117732      111.335635              0.100295
# min                -122.453704        3.000000             37.317298
# ...

# %% [markdown]
# ### What is the structure of your dataset?
#
# > The dataset contains 25 columns and 174952 rows.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > trip duration <br>
# > member gender <br>
# > member age
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > user_type <br>
# > bike_share_for_all_trip <br>
# > member_gender <br>
# > duration_sec/min <br>
# > distance <br>
# > week day <br>
# > time <br>

# %% [markdown]
# ## Univariate Exploration

# %% [markdown]
# > What is the diference in count between user_type (Customer vs Subscriber)?

# %%
sb.histplot(x='user_type', data=df);
ax = plt.gca()
ax.set_title("Difference in number between user types")
# Out:
# Text(0.5, 1.0, 'Difference in number between user types')

# %% [markdown]
# > What is the relationship of diferent non objet/string types in the dataset?

# %%
#On the kernel terminal i have updated seaborn to work with later functions e.g histplot
cols = 5
rows = 5
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
sb.set(rc={'figure.figsize':(11.7,8.27)})
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sb.histplot(x = df[col], ax = ax)
    
fig.tight_layout()  
plt.show()

ax = plt.gca()
ax.set_title("Histogram for non string types");

# %% [markdown]
# > From the histograms above we can deduce that Duration period and distance the distribution is rightly skewed <br>
# > The start year depicts data available is of just one year <br>
# > From the station_id we can conclude that some stations have a higher number of traffic as compared to others

# %% [markdown]
# > What is the diference in density distribution of gender types?

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})
sb.kdeplot(x='duration_min', data=df, hue='member_gender',log_scale=True)

ax = plt.gca()
ax.set_title("Difference in Number of gender types")
# Out:
# Text(0.5, 1.0, 'Difference in Number of gender types')

# %% [markdown]
# > Men ride bikes more as compared to other and female gender

# %% [markdown]
# > How much distance on average is traveled?

# %%
sb.violinplot(x=df['distance_km'],bw=.15,scale='area')

ax = plt.gca()
ax.set_title("Avarege distance travelled")
# Out:
# Text(0.5, 1.0, 'Avarege distance travelled')

# %% [markdown]
# > The avarage distance in kilimeters traveled is about 2KM

# %% [markdown]
# > What is the number of bike rides for each day?

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})
sb.histplot(x='start_day', data=df)

ax = plt.gca()
ax.set_title("Number of bike rides for each day")
# Out:
# Text(0.5, 1.0, 'Number of bike rides for each day')

# %% [markdown]
# > Thursday had the most number of bike rides follwed by teusday <br>
# > There is no significant difference in bike rides between Saturday and Sunday one can conclude the bikes are maily used to commute to work.

# %% [markdown]
# ## Bivariate Exploration

# %% [markdown]
# >What is the distance on bike for gender types?

# %%
sb.barplot(
    x='member_gender', 
    y='distance_km', 
    data=df, 
   );

ax = plt.gca()
ax.set_title("Distance on bike for gender types")
# Out:
# Text(0.5, 1.0, 'Distance on bike for gender types')

# %% [markdown]
# > Other gender travelled the most distance followed by female and lastly males

# %% [markdown]
# > What is the duration on the bikes for gender types?

# %%
sb.barplot(
    x='member_gender', 
    y='duration_min', 
    data=df, 
   );

ax = plt.gca()
ax.set_title("Duration on bike for gender types")
# Out:
# Text(0.5, 1.0, 'Duration on bike for gender types')

# %% [markdown]
# > Other gender travelled rode the bike for a long time followed by females and lastly males

# %% [markdown]
# > What is the avarage distance traveled per day?

# %%
plt.figure(
    figsize=(12, 6))
sb.stripplot(
    x='start_day', 
    y='distance_km', 
    data=df, 
    linewidth=.5, 
    color='blue')
plt.xticks(rotation=90);

ax = plt.gca()
ax.set_title(" Distance per day")
# Out:
# Text(0.5, 1.0, ' Distance per day')

# %% [markdown]
# > There is no significant diference of the distance travelled on any day of the week.

# %% [markdown]
# > What is the relationship between distance and time on bike?

# %%
sb.jointplot(
    x='duration_min', 
    y='distance_km', 
    data=df);

ax = plt.gca()
ax.set_title("Relationship between distance and time on bike")
# Out:
# Text(0.5, 1.0, 'Relationship between distance and time on bike')

# %% [markdown]
# > There is little to no correlation between distance and time spent of the bike.

# %% [markdown]
# > What is the distance travelled for each gender type?

# %%
sb.displot(df,x="member_gender", y="distance_km")  
sb.set(rc={'figure.figsize':(16.7,11.27)})
ax = plt.gca()
ax.set_title("Distance travelled for genders")
# Out:
# Text(0.5, 1.0, 'Distance travelled for genders')

# %% [markdown]
# > On avarage more men traveled futher in terms of distance

# %% [markdown]
# ## Multivariate Exploration

# %% [markdown]
# > What is the distace travelled in time for each user type?

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})
sb.scatterplot(
    x='duration_min',
    y='distance_km', 
    data=df,
    palette='bright',
    hue='user_type');

ax = plt.gca()
ax.set_title("Distace travelled in time for user_type")
# Out:
# Text(0.5, 1.0, 'Distace travelled in time for user_type')

# %% [markdown]
# >customers spend more time on average compare to subscribers and travell further.

# %% [markdown]
# > What is the distance travelled in time for each gender?

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})
sb.lmplot(
    x="duration_min", 
    y="distance_km", 
    data=df,
    palette='bright',
    hue="member_gender");

ax = plt.gca()
ax.set_title("Distance travelled in time for genders")
# Out:
# Text(0.5, 1.0, 'Distance travelled in time for genders')

# %% [markdown]
# > Men tend to travel further in respect to time followed my females and finally other gender

# %% [markdown]
# > Who shares bikes more often accross user types?

# %%
plt.title('Trip bike share between genders')
sb.barplot(
    x='member_gender', 
    y='distance_km', 
    data=df, 
    palette='Paired',
    hue='bike_share_for_all_trip');

# %% [markdown]
# > Less females tend to share bikes then males and other gender tend to equally share than not.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Trip duration varies extremely between subscribers and customers.
#
# ### Were there any interesting or surprising interactions between features?
#
# > None it was as expected.

# %% [markdown]
# Conclusions
# Most customers are from the subsciber group. Also men were the majority of gender who took bike rides.
#
# Customers spend more time on bike rides compared to subscribers, This can be argued to be as a result that subscribers could be taking a fixed route to reccuring locations of short distances e.g work or engagement of reccuring nature and that customers could be a leisure activity and hence more time is spend of rides to maximise the pay for a given day.
